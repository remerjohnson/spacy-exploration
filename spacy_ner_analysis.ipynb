# %% [markdown]
# # SpaCy Text Analysis for Named Entity Recognition
# The goal of this notebook is to explore NER (Named Entity Recognition) with regard to mostly geographic places, analyzing some typical DAMS metadata from the Pacific Basin Nautical Charts.

# %%
import spacy
import pandas as pd
import numpy as np

# %%
'''
This command might take a little while. First download this module via:
$ python -m spacy download en_core_web_sm
'''  
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Setting up the `pandas` dataframe

# %%
# load in our Excel as a pandas dataframe 
df = pd.read_excel('data/sio_hist_charts.xlsx')

# %%
df.head()
# Out:
#     Row       File Name                                           JPEG URL  \
# 0    16  HY00000123.tif  https://libraries.ucsd.edu/apps/public/#DOV&bb...
# 1   634  HY00000082.tif  https://libraries.ucsd.edu/apps/public/#DOV&bb...
# 2   633  HY00005861.tif  https://libraries.ucsd.edu/apps/public/#DOV&bb...
# 3  1043  HY00005862.tif  https://libraries.ucsd.edu/apps/public/#DOV&bb...
# 4   725  HY00015010.tif  https://libraries.ucsd.edu/apps/public/#DOV&bb...
#
#              ARK                                              Title  \
# 0  bb07179095     Abaiang or Charlotte Island; Tarawa or Cook Is...
# 1  bb3823744m         Ahe and Manihi or Peacock and Wilsons Islands
# 2  bb51206842             Anchorages in the Netherlands West Indies
# 3  bb16735538                 Anchorages on the south coast of Java
# 4  bb2868103r     Anchorages on the southeastern coast of Kamchatka
#
#                                    Survey Note          Scale      N  \
# 0                            U.S. Ex. Ex. 1844  Scales differ   2.00
# 1                       By the U.S.Ex.Ex. 1839      1:143,441 -14.33
# 2  From Netherlands Government surveys to 1933  Scales differ  -4.62
# 3   From Netherlands Government survey in 1928  Scales differ  -8.48
# 4       Emergency reprodution of Russian chart  Scales differ    NaN
#
#            S       W  ...   Edition Date Created Date Issued  \
# 0   1.333333  172.45  ...  12th ed.   1932-05-01  1951-10-01
# 1 -14.500000 -146.50  ...  11th ed.   1921-07-01  1949-12-01
# 2  -8.780000  115.82  ...   1st ed.   1944-03-01  1944-03-01
# 3  -8.600000  113.82  ...   1st ed.   1942-12-01  1944-05-01
# 4        NaN     NaN  ...       NaN   1941-01-01  1941-01-01
#
#           Corporate author/Publisher  \
# 0  United States Hydrographic Office
# 1  United States Hydrographic Office
# 2  United States Hydrographic Office
# 3  United States Hydrographic Office
# 4  United States Hydrographic Office
#
#                                             Contents  \
# 0                                                NaN
# 1                                                NaN
# 2  Laurot Islands (Poelau Laoet Ketjil), Mata Sir...
# 3      Permisan Bay; Bandi Alit Bay; Radjeg Wesi Bay
# 4  Anchorage at Cape Olga; Entrance to the mouth ...
#
#                                               Insets  \
# 0                                                NaN
# 1  Entrance to Ahe Lagoon; Entrance to Manihi Lagoon
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Geographic Subject (geonames)                     Country (geonames)  \
# 0  Abaiang Island; Tarawa Atoll                               Kiribati
# 1                   Ahe; Manihi  Tuamotu Archipelago, French Polynesia
# 2                           NaN                              Indonesia
# 3                          Java                              Indonesia
# 4           Kamchatka Peninsula                                 Russia
#
#                                                Notes            Genre
# 0          Depths shown by soundings and pictorially  Nautical charts
# 1  Relief shown by shading; depths shown by sound...  Nautical charts
# 2  Relief shown by contours and spot heights; dep...  Nautical charts
# 3  Relief shown by form lines and spot heights; d...  Nautical charts
# 4  Relief shown by hachures; depths shown by soun...  Nautical charts
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Using SpaCy's `nlp` to get tokens
# We might be able to do NER directly, but first let's try to do the `nlp` on a column, "Title", and put it in a new column. This will give us a column of tokens

# %%
df['tokens'] = df['Title'].apply(nlp)

# %%
df.head()
# Out:
#     Row       File Name                                           JPEG URL  \
# 0    16  HY00000123.tif  https://libraries.ucsd.edu/apps/public/#DOV&bb...
# 1   634  HY00000082.tif  https://libraries.ucsd.edu/apps/public/#DOV&bb...
# 2   633  HY00005861.tif  https://libraries.ucsd.edu/apps/public/#DOV&bb...
# 3  1043  HY00005862.tif  https://libraries.ucsd.edu/apps/public/#DOV&bb...
# 4   725  HY00015010.tif  https://libraries.ucsd.edu/apps/public/#DOV&bb...
#
#              ARK                                              Title  \
# 0  bb07179095     Abaiang or Charlotte Island; Tarawa or Cook Is...
# 1  bb3823744m         Ahe and Manihi or Peacock and Wilsons Islands
# 2  bb51206842             Anchorages in the Netherlands West Indies
# 3  bb16735538                 Anchorages on the south coast of Java
# 4  bb2868103r     Anchorages on the southeastern coast of Kamchatka
#
#                                    Survey Note          Scale      N  \
# 0                            U.S. Ex. Ex. 1844  Scales differ   2.00
# 1                       By the U.S.Ex.Ex. 1839      1:143,441 -14.33
# 2  From Netherlands Government surveys to 1933  Scales differ  -4.62
# 3   From Netherlands Government survey in 1928  Scales differ  -8.48
# 4       Emergency reprodution of Russian chart  Scales differ    NaN
#
#            S       W  ...  Date Created Date Issued  \
# 0   1.333333  172.45  ...    1932-05-01  1951-10-01
# 1 -14.500000 -146.50  ...    1921-07-01  1949-12-01
# 2  -8.780000  115.82  ...    1944-03-01  1944-03-01
# 3  -8.600000  113.82  ...    1942-12-01  1944-05-01
# 4        NaN     NaN  ...    1941-01-01  1941-01-01
#
#           Corporate author/Publisher  \
# 0  United States Hydrographic Office
# 1  United States Hydrographic Office
# 2  United States Hydrographic Office
# 3  United States Hydrographic Office
# 4  United States Hydrographic Office
#
#                                             Contents  \
# 0                                                NaN
# 1                                                NaN
# 2  Laurot Islands (Poelau Laoet Ketjil), Mata Sir...
# 3      Permisan Bay; Bandi Alit Bay; Radjeg Wesi Bay
# 4  Anchorage at Cape Olga; Entrance to the mouth ...
#
#                                               Insets  \
# 0                                                NaN
# 1  Entrance to Ahe Lagoon; Entrance to Manihi Lagoon
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Geographic Subject (geonames)                     Country (geonames)  \
# 0  Abaiang Island; Tarawa Atoll                               Kiribati
# 1                   Ahe; Manihi  Tuamotu Archipelago, French Polynesia
# 2                           NaN                              Indonesia
# 3                          Java                              Indonesia
# 4           Kamchatka Peninsula                                 Russia
#
#                                                Notes            Genre  \
# 0          Depths shown by soundings and pictorially  Nautical charts
# 1  Relief shown by shading; depths shown by sound...  Nautical charts
# 2  Relief shown by contours and spot heights; dep...  Nautical charts
# 3  Relief shown by form lines and spot heights; d...  Nautical charts
# 4  Relief shown by hachures; depths shown by soun...  Nautical charts
#
#                                               tokens
# 0  (Abaiang, or, Charlotte, Island, ;, Tarawa, or...
# 1  (Ahe, and, Manihi, or, Peacock, and, Wilsons, ...
# 2   (Anchorages, in, the, Netherlands, West, Indies)
# 3      (Anchorages, on, the, south, coast, of, Java)
# 4  (Anchorages, on, the, southeastern, coast, of,...
#
# [5 rows x 23 columns]

# %%
df['tokens']
# Out:
# 0       (Abaiang, or, Charlotte, Island, ;, Tarawa, or...
# 1       (Ahe, and, Manihi, or, Peacock, and, Wilsons, ...
# 2        (Anchorages, in, the, Netherlands, West, Indies)
# 3           (Anchorages, on, the, south, coast, of, Java)
# 4       (Anchorages, on, the, southeastern, coast, of,...
# 5       (Asia, :, anchorages, on, the, south, coast, o...
# 6       (Asia, :, anchorages, on, the, west, coast, of...
# 7       (Asia, :, anchorages, on, the, west, coast, of...
# 8       (Asia, :, Cambodia, -, Thailand, :, Gulf, of, ...
# 9       (Asia, :, China, :, approaches, to, the, Yangt...
# 10      (Asia, :, China, :, Chu, Kiang, or, Canton, Ri...
# 11      (Asia, :, China, :, Gulf, of, Liaotung, :, Hu,...
# 12      (Asia, :, China, :, Gulf, of, Liaotung, :, Hun...
# 13      (Asia, :, China, :, Gulf, of, Liaotung, :, Tai...
# 14      (Asia, :, China, :, Gulf, of, Pohai, :, Pei, H...
# 15      (Asia, :, China, :, Kwantung, Peninsula, :, Da...
# 16      (Asia, :, China, :, Liaodong, Wan, (, Liao, -,...
# 17      (Asia, :, China, :, Liaotung, Gulf, :, approac...
# 18                  (Asia, :, China, :, Tsingtao, Harbor)
# 19      (Asia, :, China, :, Upper, Yangtze, Kiang, -, ...
# 20      (Asia, :, China, :, Yangtze, River, :, Nanking...
# 21      (Asia, :, China, :, Yangtze, River, :, Shangha...
# 22      (Asia, :, China, :, Yellow, Sea, (, Hwang, Hai...
# 23      (Asia, :, China, Canton, River, :, Whampao, to...
# 24      (Asia, :, China, east, coast, :, Chusan, Archi...
# 25      (Asia, :, China, north, coast, :, Chin, -, Cho...
# 26      (Asia, :, China, south, coast, :, Hainan, Stra...
# 27      (Asia, :, China, south, coast, :, Plans, on, H...
# 28      (Asia, :, China, -, east, coast,  , :, channel...
# 29      (Asia, :, China, -, east, coast, :, Amoy, (, H...
#                               ...
# 1016    (South, Pacific, Ocean, :, Tonga, Islands, :, ...
# 1017    (South, Pacific, Ocean, :, Tonga, Islands, :, ...
# 1018    (South, Pacific, Ocean, :, Tonga, Islands, :, ...
# 1019    (South, Pacific, Ocean, :, Tonga, Islands, :, ...
# 1020    (South, Pacific, Ocean, :, Tonga, or, Friendly...
# 1021    (South, Pacific, Ocean, :, Tonga, or, Friendly...
# 1022    (South, Pacific, Ocean, :, Tongatabu, Island, ...
# 1023     (South, Pacific, Ocean, :, Tuamotu, Archipelago)
# 1024    (South, Pacific, Ocean, :, Tuamotu, Archipelag...
# 1025    (South, Pacific, Ocean, :, Tuamotu, Archipelag...
# 1026    (South, Pacific, Ocean, :, Tuamotu, Group, :, ...
# 1027    (South, Pacific, Ocean, :, Tuamotu, Group, :, ...
# 1028    (South, Pacific, Ocean, :, Tumamotu, Archipela...
# 1029    (South, Pacific, Ocean, :, Vietnam, :, Mui, Ba...
# 1030    (South, Pacific, Ocean, :, Wallis, Islands, -,...
# 1031    (Southeast, Asia, :, anchorages, on, the, cent...
# 1032    (Southeast, coast, of, Borneo, :, approaches, ...
# 1033    (South, -, west, Pacific, :, plans, of, anchor...
# 1034            (Soya, Kaikyo, (, La, Perouse, Strait, ))
# 1035    (S, -, Stiller, Ozean, :, Bismarck, Archipel, ...
# 1036    (S, -, Stiller, Ozean, :, Bismarck, Archipel, ...
# 1037    (Stiller, Ocean, :, Neu, -, Guinea, :, Kaiser,...
# 1038    (Taiwan, (, Formosa)-east, coast, :, T'ai, -, ...
# 1039    (Taiwan, (, Formosa)-west, coast, :, Fang, -, ...
# 1040      (Taiwan, :, north, coast, :, Chi, -, Lung, Kan)
# 1041    (Taiwan, -, west, coast, :, Hai, -, K'ou, Po, ...
# 1042    (Taiwan, -, west, coast, :, O, -, Luan, Pi, to...
# 1043      (Tuamotu, Archipelago, :, King, Georges, Group)
# 1044                                     (Tuamotu, Group)
# 1045    (USSR, -, Sea, of, Japan, :, southeast, coast,...
# Name: tokens, Length: 1046, dtype: object

# %%
df['entities'] = df['Title'].apply(lambda x: list(nlp(x).ents))

# %%
df['entities']
# Out:
# 0       [(Abaiang), (Charlotte, Island), (Tarawa), (Co...
# 1                   [(Ahe), (Manihi), (Wilsons, Islands)]
# 2                                                      []
# 3                                                      []
# 4                                           [(Kamchatka)]
# 5                                       [(Asia), (China)]
# 6                             [(Asia), (Chosen), (Korea)]
# 7                             [(Asia), (Chosen), (Korea)]
# 8       [(Asia), (Cambodia), (Thailand), (Thailand), (...
# 9                [(Asia), (China), (the, Yangtze, River)]
# 10      [(Asia), (China), (Chu, Kiang), (Canton, River...
# 11                         [(Asia), (China), (Hu, -, Lu)]
# 12      [(Asia), (China), (Fort, Head), (Chin, -, Chou...
# 13      [(Asia), (China), (Tai, -, Tzu), (Fu, -, Chou,...
# 14      [(Asia), (China), (Pohai), (Hai, Ho), (2), (Ko...
# 15      [(Asia), (China), (Kwantung, Peninsula), (Dair...
# 16      [(Asia), (China), (Liaodong, Wan), (Liao, -, T...
# 17                    [(Asia), (China), (Liaotung, Gulf)]
# 18                  [(Asia), (China), (Tsingtao, Harbor)]
# 19      [(Asia), (China), (Upper, Yangtze, Kiang, -, H...
# 20         [(Asia), (China), (Yangtze, River), (Tungliu)]
# 21      [(Asia), (China), (Yangtze, River), (Shanghai)...
# 22      [(Asia), (China), (Yellow, Sea), (Hwang, Hai),...
# 23      [(Asia), (China, Canton, River), (Whampao), (C...
# 24                           [(Asia), (China), (Tinghai)]
# 25      [(Asia), (China), (Chin, -, Chou, Wan), (Kuang...
# 26      [(Asia), (China), (Hainan, Strait), (Hoihow, B...
# 27      [(Asia), (China), (Hai, -, Nan, Tao), (Hainan,...
# 28      [(Asia), (China), (Red, Yit), (Rugged, Island)...
# 29                 [(Asia), (China), (Amoy), (Hsia, Men)]
#                               ...
# 1016    [(South, Pacific, Ocean), (Tonga, Islands), (H...
# 1017    [(South, Pacific, Ocean), (Tonga, Islands), (H...
# 1018          [(South, Pacific, Ocean), (Tonga, Islands)]
# 1019          [(South, Pacific, Ocean), (Tonga, Islands)]
# 1020    [(South, Pacific, Ocean), (Tonga), (Friendly, ...
# 1021    [(South, Pacific, Ocean), (Tonga), (Friendly, ...
# 1022    [(South, Pacific, Ocean, :), (Tongatabu, Islan...
# 1023                            [(South, Pacific, Ocean)]
# 1024              [(South, Pacific, Ocean), (Islands, -)]
# 1025      [(South, Pacific, Ocean), (Rangiroa), (Makemo)]
# 1026    [(South, Pacific, Ocean), (Tuamotu, Group), (F...
# 1027    [(South, Pacific, Ocean), (Tuamotu, Group), (A...
# 1028                [(South, Pacific, Ocean), (Magareva)]
# 1029                 [(South, Pacific, Ocean), (Vietnam)]
# 1030    [(South, Pacific, Ocean), (Wallis, Islands, -,...
# 1031                       [(Southeast, Asia), (Vietnam)]
# 1032                             [(Borneo), (Pulu, Laut)]
# 1033                           [(Pacific), (New, Guinea)]
# 1034              [(Soya, Kaikyo), (La, Perouse, Strait)]
# 1035    [(S, -, Stiller, Ozean), (Bismarck, Archipel),...
# 1036    [(S, -, Stiller, Ozean), (Bismarck, Archipel, ...
# 1037                 [(Stiller, Ocean), (Neu, -, Guinea)]
# 1038                         [(Taiwan), (O, -, Luan, Pi)]
# 1039    [(Taiwan), (Fang, -, Liao, Chiang), (Kao, -, H...
# 1040                      [(Taiwan), (Chi, -, Lung, Kan)]
# 1041    [(Taiwan), (Po, -, Ti), (Chiu, -, Kang, Po, -,...
# 1042    [(Taiwan), (O, -, Luan, Pi), (Kao, -, Hsiung, ...
# 1043                                                   []
# 1044                                   [(Tuamotu, Group)]
# 1045    [(USSR), (Japan), (Siberia), (Vladivostock, Ha...
# Name: entities, Length: 1046, dtype: object

# %% [markdown]
# ## Using `displacy` to visualize entities
# We can also run some neat visualization tools on text to get a visual picture of text using `displacy`

# %%
from spacy import displacy

# %%
text = """
Louis "Lubo" Pechi was born in the Croatian city of Zagreb. He was seven years old when the Germans invaded Yugoslavia. 
In response to the mounting anti-Semitic repression and strict laws prohibiting Jews from traveling, 
the Pechis converted to Catholicism so that they could escape to safety in Italy. The move marked a lengthy process of hiding: 
Lubo had to change his name, religion, and identity. The Pechi family finally managed to escape and make their way to Rome. 
Decades later, Lubo began the arduous process of recovering the memories of his hidden life by writing 
his memoir "I am Lubo: A Child Survivor from Yugoslavia."
"""
doc = nlp(text)
displacy.render(doc, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr"></br>Louis &quot;Lubo&quot; Pechi was born in the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Croatian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  city of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Zagreb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . He was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     seven years old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  when the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Germans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  invaded
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Yugoslavia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . </br>In response to the mounting
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     anti-Semitic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  repression and strict laws prohibiting
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jews
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  from traveling, </br>the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Pechis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  converted to Catholicism so that they could escape to safety in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Italy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . The move marked a lengthy process of hiding: </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Lubo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  had to change his name, religion, and identity. The
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Pechi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  family finally managed to escape and make their way to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Rome
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . </br>Decades later,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Lubo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  began the arduous process of recovering the memories of his hidden life by writing </br>his memoir &quot;I am Lubo: A Child Survivor from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Yugoslavia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .&quot;
# </div>
